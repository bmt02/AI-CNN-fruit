# %% [markdown]
# Họ và tên : Bùi Minh Tú
#
# MSSV: 19146295
#
# Lớp AI sáng thứ 4
#
# BT: Nhận dạng 10 loại trái cây

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.convolutional import MaxPooling2D
from keras.layers.convolutional import Conv2D
from keras.layers import Dense, Activation, Flatten, Input, Dropout
from keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def loadData():
    file = open('/content/drive/MyDrive/AI/BT-CNN/fruit.data', 'rb')
    (images, labels) = pickle.load(file)
    file.close()
    print(images.shape)
    print(labels.shape)
    return images, labels

# %%
X,y = loadData()
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=100)
# Out:
# (3200, 128, 128, 3)
# (3200, 10)

# %%
model = Sequential()

# %%
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(2048, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.1,
    rescale=1./255,
	width_shift_range=0.1,
    height_shift_range=0.1,
	horizontal_flip=True,
    brightness_range=[0.2,1.5], fill_mode="nearest")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history = model.fit(aug.flow(X_train, y_train, batch_size=64),epochs=50, validation_data=aug.flow(X_test,y_test,batch_size=64), verbose=1)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 29s 404ms/step - loss: 4.9751 - accuracy: 0.1211 - val_loss: 2.2798 - val_accuracy: 0.1219
# Epoch 2/50
# 40/40 [==============================] - 16s 396ms/step - loss: 2.1606 - accuracy: 0.1863 - val_loss: 2.1378 - val_accuracy: 0.2156
# Epoch 3/50
# 40/40 [==============================] - 17s 430ms/step - loss: 2.1260 - accuracy: 0.1969 - val_loss: 2.1043 - val_accuracy: 0.2156
# Epoch 4/50
# 40/40 [==============================] - 16s 388ms/step - loss: 2.0846 - accuracy: 0.2203 - val_loss: 2.0626 - val_accuracy: 0.2547
# Epoch 5/50
# 40/40 [==============================] - 16s 391ms/step - loss: 2.0042 - accuracy: 0.2672 - val_loss: 1.9354 - val_accuracy: 0.3109
# Epoch 6/50
# 40/40 [==============================] - 16s 388ms/step - loss: 1.9397 - accuracy: 0.3117 - val_loss: 1.9056 - val_accuracy: 0.3641
# Epoch 7/50
# 40/40 [==============================] - 16s 389ms/step - loss: 1.9195 - accuracy: 0.3105 - val_loss: 1.9303 - val_accuracy: 0.3141
# Epoch 8/50
# 40/40 [==============================] - 15s 384ms/step - loss: 1.9057 - accuracy: 0.3379 - val_loss: 1.8058 - val_accuracy: 0.3609
# Epoch 9/50
# 40/40 [==============================] - 16s 387ms/step - loss: 1.8243 - accuracy: 0.3648 - val_loss: 1.7941 - val_accuracy: 0.3656
# Epoch 10/50
# 40/40 [==============================] - 16s 391ms/step - loss: 1.7356 - accuracy: 0.3949 - val_loss: 1.6924 - val_accuracy: 0.4047
# Epoch 11/50
# 40/40 [==============================] - 16s 390ms/step - loss: 1.7306 - accuracy: 0.3910 - val_loss: 1.6850 - val_accuracy: 0.4406
# Epoch 12/50
# 40/40 [==============================] - 16s 397ms/step - loss: 1.6834 - accuracy: 0.4172 - val_loss: 1.7553 - val_accuracy: 0.4016
# Epoch 13/50
# 40/40 [==============================] - 16s 394ms/step - loss: 1.6473 - accuracy: 0.4406 - val_loss: 1.6506 - val_accuracy: 0.4359
# Epoch 14/50
# 40/40 [==============================] - 16s 389ms/step - loss: 1.6375 - accuracy: 0.4426 - val_loss: 1.7239 - val_accuracy: 0.3969
# Epoch 15/50
# 40/40 [==============================] - 16s 392ms/step - loss: 1.5856 - accuracy: 0.4488 - val_loss: 1.6051 - val_accuracy: 0.4516
# Epoch 16/50
# 40/40 [==============================] - 16s 392ms/step - loss: 1.5422 - accuracy: 0.4625 - val_loss: 1.6610 - val_accuracy: 0.4609
# Epoch 17/50
# 40/40 [==============================] - 16s 392ms/step - loss: 1.5419 - accuracy: 0.4629 - val_loss: 1.5627 - val_accuracy: 0.4781
# Epoch 18/50
# 40/40 [==============================] - 16s 395ms/step - loss: 1.4934 - accuracy: 0.4871 - val_loss: 1.6142 - val_accuracy: 0.4594
# Epoch 19/50
# 40/40 [==============================] - 16s 393ms/step - loss: 1.4644 - accuracy: 0.4988 - val_loss: 1.5504 - val_accuracy: 0.4953
# Epoch 20/50
# 40/40 [==============================] - 16s 398ms/step - loss: 1.4372 - accuracy: 0.5184 - val_loss: 1.5935 - val_accuracy: 0.4766
# Epoch 21/50
# 40/40 [==============================] - 16s 394ms/step - loss: 1.4332 - accuracy: 0.5148 - val_loss: 1.5687 - val_accuracy: 0.4750
# Epoch 22/50
# 40/40 [==============================] - 16s 393ms/step - loss: 1.3591 - accuracy: 0.5473 - val_loss: 1.6596 - val_accuracy: 0.4500
# Epoch 23/50
# 40/40 [==============================] - 16s 392ms/step - loss: 1.2810 - accuracy: 0.5605 - val_loss: 1.5470 - val_accuracy: 0.5016
# Epoch 24/50
# 40/40 [==============================] - 16s 398ms/step - loss: 1.3108 - accuracy: 0.5648 - val_loss: 1.6017 - val_accuracy: 0.4734
# Epoch 25/50
# 40/40 [==============================] - 16s 393ms/step - loss: 1.2119 - accuracy: 0.5898 - val_loss: 1.5904 - val_accuracy: 0.5031
# Epoch 26/50
# 40/40 [==============================] - 16s 390ms/step - loss: 1.2157 - accuracy: 0.5793 - val_loss: 1.4668 - val_accuracy: 0.5625
# Epoch 27/50
# 40/40 [==============================] - 15s 386ms/step - loss: 1.2319 - accuracy: 0.5887 - val_loss: 1.5555 - val_accuracy: 0.5016
# Epoch 28/50
# 40/40 [==============================] - 16s 390ms/step - loss: 1.2086 - accuracy: 0.5957 - val_loss: 1.5453 - val_accuracy: 0.4969
# Epoch 29/50
# 40/40 [==============================] - 16s 392ms/step - loss: 1.1337 - accuracy: 0.6187 - val_loss: 1.6047 - val_accuracy: 0.5094
# Epoch 30/50
# 40/40 [==============================] - 16s 400ms/step - loss: 1.0569 - accuracy: 0.6387 - val_loss: 1.5320 - val_accuracy: 0.5375
# Epoch 31/50
# 40/40 [==============================] - 16s 390ms/step - loss: 1.0505 - accuracy: 0.6449 - val_loss: 1.4945 - val_accuracy: 0.5500
# Epoch 32/50
# 40/40 [==============================] - 15s 386ms/step - loss: 0.9427 - accuracy: 0.6711 - val_loss: 1.5995 - val_accuracy: 0.5641
# Epoch 33/50
# 40/40 [==============================] - 15s 386ms/step - loss: 0.9373 - accuracy: 0.6785 - val_loss: 1.5535 - val_accuracy: 0.5437
# Epoch 34/50
# 40/40 [==============================] - 18s 459ms/step - loss: 0.9078 - accuracy: 0.7055 - val_loss: 1.5800 - val_accuracy: 0.5656
# Epoch 35/50
# 40/40 [==============================] - 16s 390ms/step - loss: 0.9680 - accuracy: 0.6750 - val_loss: 1.4932 - val_accuracy: 0.5453
# Epoch 36/50
# 40/40 [==============================] - 18s 441ms/step - loss: 0.8711 - accuracy: 0.7160 - val_loss: 1.5145 - val_accuracy: 0.5500
# Epoch 37/50
# 40/40 [==============================] - 16s 390ms/step - loss: 0.8472 - accuracy: 0.7164 - val_loss: 1.6867 - val_accuracy: 0.5406
# Epoch 38/50
# 40/40 [==============================] - 16s 389ms/step - loss: 0.8116 - accuracy: 0.7406 - val_loss: 1.5980 - val_accuracy: 0.5625
# Epoch 39/50
# 40/40 [==============================] - 16s 399ms/step - loss: 0.7805 - accuracy: 0.7371 - val_loss: 1.5970 - val_accuracy: 0.5469
# Epoch 40/50
# 40/40 [==============================] - 15s 386ms/step - loss: 0.7395 - accuracy: 0.7594 - val_loss: 1.6118 - val_accuracy: 0.5703
# Epoch 41/50
# 40/40 [==============================] - 15s 383ms/step - loss: 0.7529 - accuracy: 0.7473 - val_loss: 1.6402 - val_accuracy: 0.5672
# Epoch 42/50
# 40/40 [==============================] - 15s 381ms/step - loss: 0.7673 - accuracy: 0.7426 - val_loss: 1.5458 - val_accuracy: 0.5484
# Epoch 43/50
# 40/40 [==============================] - 16s 388ms/step - loss: 0.7267 - accuracy: 0.7703 - val_loss: 1.5682 - val_accuracy: 0.5797
# Epoch 44/50
# 40/40 [==============================] - 15s 382ms/step - loss: 0.6905 - accuracy: 0.7797 - val_loss: 1.6391 - val_accuracy: 0.5469
# Epoch 45/50
# 40/40 [==============================] - 15s 380ms/step - loss: 0.7098 - accuracy: 0.7672 - val_loss: 1.8598 - val_accuracy: 0.5516
# Epoch 46/50
# 40/40 [==============================] - 20s 495ms/step - loss: 0.6445 - accuracy: 0.7926 - val_loss: 1.6690 - val_accuracy: 0.5734
# Epoch 47/50
# 40/40 [==============================] - 18s 439ms/step - loss: 0.5873 - accuracy: 0.8051 - val_loss: 1.6832 - val_accuracy: 0.5828
# Epoch 48/50
# 40/40 [==============================] - 19s 476ms/step - loss: 0.5903 - accuracy: 0.8098 - val_loss: 1.8109 - val_accuracy: 0.5437
# Epoch 49/50
# 40/40 [==============================] - 16s 394ms/step - loss: 0.5716 - accuracy: 0.8102 - val_loss: 1.8833 - val_accuracy: 0.5453
# Epoch 50/50
# 40/40 [==============================] - 15s 386ms/step - loss: 0.5717 - accuracy: 0.8121 - val_loss: 1.7884 - val_accuracy: 0.5734

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss: %.4f'% score[0])
print('Test accuracy %.4f'% score[1])
# Out:
# Test loss: 313.9739
# Test accuracy 0.5312

# %%
model.save('Final.h5')

# %%
from keras.models import load_model
model5=load_model('Final.h5')

# %%
class_name = ['Bưởi','Cam','Dưa hấu','Đu đủ','Khế','Nho','Ổi','Thanh long','Thơm','Xoài']

# %%
img = load_img('/content/nho.jpg',target_size=(128,128))
plt.imshow(img)
img = img_to_array(img)

# %%
img=img.reshape(1,128,128,3)
class_name[np.argmax(model5.predict(img),axis=1)[0]]
# Out:
# 'Nho'
